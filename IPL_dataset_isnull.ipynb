# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Match_Info.csv')
df
# Out:
#       match_number                        team1                        team2  \
# 0           336036             Rajasthan Royals               Mumbai Indians
# 1           335995              Kings XI Punjab             Delhi Daredevils
# 2          1254108  Royal Challengers Bangalore               Mumbai Indians
# 3           829761        Kolkata Knight Riders             Delhi Daredevils
# 4          1216521          Chennai Super Kings               Mumbai Indians
# ...            ...                          ...                          ...
# 1164        336017        Kolkata Knight Riders             Delhi Daredevils
# 1165        981007                Gujarat Lions               Mumbai Indians
# 1166        980931      Rising Pune Supergiants  Royal Challengers Bangalore
# 1167       1304095  Royal Challengers Bangalore          Chennai Super Kings
# 1168       1136568              Kings XI Punjab  Royal Challengers Bangalore
#
# ...

# %%
df.shape
# Out:
# (1169, 14)

# %%
df.head()
# Out:
#    match_number                        team1             team2  match_date  \
# 0        336036             Rajasthan Royals    Mumbai Indians  2008-05-26
# 1        335995              Kings XI Punjab  Delhi Daredevils  2008-04-27
# 2       1254108  Royal Challengers Bangalore    Mumbai Indians  2021-09-26
# 3        829761        Kolkata Knight Riders  Delhi Daredevils  2015-05-07
# 4       1216521          Chennai Super Kings    Mumbai Indians  2020-10-23
#
#              toss_winner toss_decision result eliminator  \
# 0       Rajasthan Royals         field    Win        NaN
# 1       Delhi Daredevils           bat    Win        NaN
# 2         Mumbai Indians         field    Win        NaN
# 3  Kolkata Knight Riders           bat    Win        NaN
# 4         Mumbai Indians         field    Win        NaN
#
#                         winner player_of_match  \
# 0             Rajasthan Royals   Sohail Tanvir
# 1              Kings XI Punjab       SM Katich
# ...

# %%
df.tail()
# Out:
#       match_number                        team1                        team2  \
# 1164        336017        Kolkata Knight Riders             Delhi Daredevils
# 1165        981007                Gujarat Lions               Mumbai Indians
# 1166        980931      Rising Pune Supergiants  Royal Challengers Bangalore
# 1167       1304095  Royal Challengers Bangalore          Chennai Super Kings
# 1168       1136568              Kings XI Punjab  Royal Challengers Bangalore
#
#       match_date                  toss_winner toss_decision result eliminator  \
# 1164  2008-05-13        Kolkata Knight Riders           bat    Win        NaN
# 1165  2016-05-21                Gujarat Lions         field    Win        NaN
# 1166  2016-04-22      Rising Pune Supergiants         field    Win        NaN
# 1167  2022-05-04          Chennai Super Kings         field    Win        NaN
# 1168  2018-04-13  Royal Challengers Bangalore         field    Win        NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_number     1169 non-null   int64
#  1   team1            1169 non-null   object
#  2   team2            1169 non-null   object
#  3   match_date       1169 non-null   object
#  4   toss_winner      1169 non-null   object
#  5   toss_decision    1169 non-null   object
#  6   result           1169 non-null   object
#  7   eliminator       15 non-null     object
#  8   winner           1146 non-null   object
#  9   player_of_match  1169 non-null   object
#  10  venue            1169 non-null   object
#  11  city             1118 non-null   object
#  12  team1_players    1169 non-null   object
#  13  team2_players    1169 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 128.0+ KB

# %%
df.describe()
# Out:
#        match_number
# count  1.169000e+03
# mean   9.408352e+05
# std    3.819244e+05
# min    3.359820e+05
# 25%    5.483520e+05
# 50%    1.082598e+06
# 75%    1.304047e+06
# max    1.485779e+06

# %%
df.columns
# Out:
# Index(['match_number', 'team1', 'team2', 'match_date', 'toss_winner',
#        'toss_decision', 'result', 'eliminator', 'winner', 'player_of_match',
#        'venue', 'city', 'team1_players', 'team2_players'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       match_number  team1  team2  match_date  toss_winner  toss_decision  \
# 0            False  False  False       False        False          False
# 1            False  False  False       False        False          False
# 2            False  False  False       False        False          False
# 3            False  False  False       False        False          False
# 4            False  False  False       False        False          False
# ...            ...    ...    ...         ...          ...            ...
# 1164         False  False  False       False        False          False
# 1165         False  False  False       False        False          False
# 1166         False  False  False       False        False          False
# 1167         False  False  False       False        False          False
# 1168         False  False  False       False        False          False
#
#       result  eliminator  winner  player_of_match  venue   city  \
# ...

# %%
df.isnull().sum()
# Out:
# match_number          0
# team1                 0
# team2                 0
# match_date            0
# toss_winner           0
# toss_decision         0
# result                0
# eliminator         1154
# winner               23
# player_of_match       0
# venue                 0
# city                 51
# team1_players         0
# team2_players         0
# dtype: int64

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
null_var =df.isnull().sum()/len(df)*100
null_var
# Out:
# match_number        0.000000
# team1               0.000000
# team2               0.000000
# match_date          0.000000
# toss_winner         0.000000
# toss_decision       0.000000
# result              0.000000
# eliminator         98.716852
# winner              1.967494
# player_of_match     0.000000
# venue               0.000000
# city                4.362703
# team1_players       0.000000
# team2_players       0.000000
# dtype: float64

# %%
drop_column = null_var[null_var>98].keys()
drop_column
# Out:
# Index(['eliminator'], dtype='object')

# %%
df_drop_clm = df.drop(columns=drop_column)
df_drop_clm.shape
# Out:
# (1169, 13)

# %%
sns.heatmap(df_drop_clm.isnull())
# Out:
# <Axes: >

# %%
df_drop_rows = df_drop_clm.dropna()
df_drop_rows
# Out:
#       match_number                        team1                        team2  \
# 0           336036             Rajasthan Royals               Mumbai Indians
# 1           335995              Kings XI Punjab             Delhi Daredevils
# 2          1254108  Royal Challengers Bangalore               Mumbai Indians
# 3           829761        Kolkata Knight Riders             Delhi Daredevils
# 5           733977  Royal Challengers Bangalore          Sunrisers Hyderabad
# ...            ...                          ...                          ...
# 1164        336017        Kolkata Knight Riders             Delhi Daredevils
# 1165        981007                Gujarat Lions               Mumbai Indians
# 1166        980931      Rising Pune Supergiants  Royal Challengers Bangalore
# 1167       1304095  Royal Challengers Bangalore          Chennai Super Kings
# 1168       1136568              Kings XI Punjab  Royal Challengers Bangalore
#
# ...

# %%
sns.heatmap(df_drop_rows.isnull())
# Out:
# <Axes: >
