# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv('dataset(2).csv')
df
# Out:
#     Item no   Outlook  Temp Humidity  Windy Play
# 0         1     Sunny   Hot     High  False   No
# 1         2     Sunny   Hot     High   True   No
# 2         3  Overcast   Hot     High  False  Yes
# 3         4     Rainy  Mild     High  False  Yes
# 4         5     Rainy  Cool   Normal  False  Yes
# 5         6     Rainy  Cool   Normal   True   No
# 6         7  Overcast  Cool   Normal   True  Yes
# 7         8     Sunny  Mild     High  False   No
# 8         9     Sunny  Cool   Normal  False  Yes
# 9        10     Rainy  Mild   Normal  False  Yes
# 10       11     Sunny  Mild   Normal   True  Yes
# 11       12  Overcast  Mild     High   True  Yes
# 12       13  Overcast   Hot   Normal  False  Yes
# 13       14     Rainy  Mild     High   True   No
# 14       15     Sunny   Hot     High  False   No
# 15       16     Sunny   Hot     High   True   No
# 16       17  Overcast   Hot     High  False  Yes
# 17       18     Rainy  Mild     High  False  Yes
# 18       19     Rainy  Cool   Normal  False  Yes
# 19       20     Rainy  Cool   Normal   True   No
# 20       21  Overcast  Cool   Normal   True  Yes
# 21       22     Sunny  Mild     High  False   No
# 22       23     Sunny  Cool   Normal  False  Yes
# 23       24     Rainy  Mild   Normal  False  Yes
# 24       25     Sunny  Mild   Normal   True  Yes
# 25       26  Overcast  Mild     High   True  Yes
# 26       27  Overcast   Hot   Normal  False  Yes
# 27       28     Rainy  Mild     High   True   No

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
print(x)
print(y)
# Out:
# [[1 'Sunny' 'Hot' 'High' False]
#  [2 'Sunny' 'Hot' 'High' True]
#  [3 'Overcast' 'Hot' 'High' False]
#  [4 'Rainy' 'Mild' 'High' False]
#  [5 'Rainy' 'Cool' 'Normal' False]
#  [6 'Rainy' 'Cool' 'Normal' True]
#  [7 'Overcast' 'Cool' 'Normal' True]
#  [8 'Sunny' 'Mild' 'High' False]
#  [9 'Sunny' 'Cool' 'Normal' False]
#  [10 'Rainy' 'Mild' 'Normal' False]
#  [11 'Sunny' 'Mild' 'Normal' True]
#  [12 'Overcast' 'Mild' 'High' True]
#  [13 'Overcast' 'Hot' 'Normal' False]
#  [14 'Rainy' 'Mild' 'High' True]
#  [15 'Sunny' 'Hot' 'High' False]
#  [16 'Sunny' 'Hot' 'High' True]
#  [17 'Overcast' 'Hot' 'High' False]
#  [18 'Rainy' 'Mild' 'High' False]
#  [19 'Rainy' 'Cool' 'Normal' False]
#  [20 'Rainy' 'Cool' 'Normal' True]
#  [21 'Overcast' 'Cool' 'Normal' True]
#  [22 'Sunny' 'Mild' 'High' False]
#  [23 'Sunny' 'Cool' 'Normal' False]
#  [24 'Rainy' 'Mild' 'Normal' False]
#  [25 'Sunny' 'Mild' 'Normal' True]
#  [26 'Overcast' 'Mild' 'High' True]
#  [27 'Overcast' 'Hot' 'Normal' False]
#  [28 'Rainy' 'Mild' 'High' True]]
# ['No' 'No' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'No']

# %%
x=pd.DataFrame(x)
y=pd.DataFrame(y)
print(x)
print(y)
# Out:
#      0         1     2       3      4
# 0    1     Sunny   Hot    High  False
# 1    2     Sunny   Hot    High   True
# 2    3  Overcast   Hot    High  False
# 3    4     Rainy  Mild    High  False
# 4    5     Rainy  Cool  Normal  False
# 5    6     Rainy  Cool  Normal   True
# 6    7  Overcast  Cool  Normal   True
# 7    8     Sunny  Mild    High  False
# 8    9     Sunny  Cool  Normal  False
# 9   10     Rainy  Mild  Normal  False
# 10  11     Sunny  Mild  Normal   True
# 11  12  Overcast  Mild    High   True
# 12  13  Overcast   Hot  Normal  False
# 13  14     Rainy  Mild    High   True
# 14  15     Sunny   Hot    High  False
# 15  16     Sunny   Hot    High   True
# 16  17  Overcast   Hot    High  False
# 17  18     Rainy  Mild    High  False
# 18  19     Rainy  Cool  Normal  False
# 19  20     Rainy  Cool  Normal   True
# 20  21  Overcast  Cool  Normal   True
# 21  22     Sunny  Mild    High  False
# 22  23     Sunny  Cool  Normal  False
# 23  24     Rainy  Mild  Normal  False
# 24  25     Sunny  Mild  Normal   True
# 25  26  Overcast  Mild    High   True
# 26  27  Overcast   Hot  Normal  False
# 27  28     Rainy  Mild    High   True
#       0
# 0    No
# 1    No
# 2   Yes
# 3   Yes
# 4   Yes
# 5    No
# 6   Yes
# 7    No
# 8   Yes
# 9   Yes
# 10  Yes
# 11  Yes
# 12  Yes
# 13   No
# 14   No
# 15   No
# 16  Yes
# 17  Yes
# 18  Yes
# 19   No
# 20  Yes
# 21   No
# 22  Yes
# 23  Yes
# 24  Yes
# 25  Yes
# 26  Yes
# 27   No

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder_x=LabelEncoder()
x.values[:,0]=LabelEncoder_x.fit_transform(x.values[:,0])
x.values[:,1]=LabelEncoder_x.fit_transform(x.values[:,1])
x.values[:,2]=LabelEncoder_x.fit_transform(x.values[:,2])
x.values[:,3]=LabelEncoder_x.fit_transform(x.values[:,3])
y.values[:,0]=LabelEncoder_x.fit_transform(x.values[:,0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
x_train = x_train.astype(float)
y_train = y_train.astype(float)
x_test = x_test.astype(float)
y_test = y_test.astype(float)

# %%
x_train
# Out:
#        0    1    2    3    4
# 24  24.0  2.0  2.0  1.0  1.0
# 13  13.0  1.0  2.0  0.0  1.0
# 20  20.0  0.0  0.0  1.0  1.0
# 25  25.0  0.0  2.0  0.0  1.0
# 16  16.0  0.0  1.0  0.0  0.0
# 1    1.0  2.0  1.0  0.0  1.0
# 10  10.0  2.0  2.0  1.0  1.0
# 27  27.0  1.0  2.0  0.0  1.0
# 26  26.0  0.0  1.0  1.0  0.0
# 8    8.0  2.0  0.0  1.0  0.0
# 6    6.0  0.0  0.0  1.0  1.0
# 4    4.0  1.0  0.0  1.0  0.0
# 18  18.0  1.0  0.0  1.0  0.0
# 19  19.0  1.0  0.0  1.0  1.0
# 9    9.0  1.0  2.0  1.0  0.0
# 7    7.0  2.0  2.0  0.0  0.0
# 23  23.0  1.0  2.0  1.0  0.0
# 3    3.0  1.0  2.0  0.0  0.0
# 0    0.0  2.0  1.0  0.0  0.0
# 21  21.0  2.0  2.0  0.0  0.0
# 15  15.0  2.0  1.0  0.0  1.0
# 12  12.0  0.0  1.0  1.0  0.0

# %%
y_train
# Out:
#        0
# 24  24.0
# 13  13.0
# 20  20.0
# 25  25.0
# 16  16.0
# 1    1.0
# 10  10.0
# 27  27.0
# 26  26.0
# 8    8.0
# 6    6.0
# 4    4.0
# 18  18.0
# 19  19.0
# 9    9.0
# 7    7.0
# 23  23.0
# 3    3.0
# 0    0.0
# 21  21.0
# 15  15.0
# 12  12.0

# %%
x_test
# Out:
#        0    1    2    3    4
# 2    2.0  0.0  1.0  0.0  0.0
# 22  22.0  2.0  0.0  1.0  0.0
# 14  14.0  2.0  1.0  0.0  0.0
# 17  17.0  1.0  2.0  0.0  0.0
# 5    5.0  1.0  0.0  1.0  1.0
# 11  11.0  0.0  2.0  0.0  1.0

# %%
y_test
# Out:
#        0
# 2    2.0
# 22  22.0
# 14  14.0
# 17  17.0
# 5    5.0
# 11  11.0
